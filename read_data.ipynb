# %%
import matplotlib.pyplot as plt

# %%
with open("test.txt", 'r') as f:
    data = f.read()

data = data.split(',')
data = data[:-1]
data = [float(x) for x in data]

# %%
fig, ax = plt.subplots()
ax.plot([i for i,x in enumerate(data)], data, 'ro')
